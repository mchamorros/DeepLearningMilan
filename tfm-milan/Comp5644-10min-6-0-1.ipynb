# %%
import pandas as pd

# %% [markdown]
# # Comparacion de datos 6-0-1

# %% [markdown]
# ## Datos LSTM Model 5644 6-0-1

# %%
#OK
singleModel5644Acc = pd.DataFrame({})
singleModel5644Mse = pd.DataFrame({})
for index in range(0,3):
    singleModel5644OneAcc = pd.read_csv('transformed_data/model5644-6-0-1-acc_LSTM_'+str(index).zfill(1) +'.csv')
    singleModel5644OneMse = pd.read_csv('transformed_data/model5644-6-0-1-mse_LSTM_'+str(index).zfill(1) +'.csv')
    singleModel5644Acc = singleModel5644Acc.append(singleModel5644OneAcc)
    singleModel5644Mse = singleModel5644Mse.append(singleModel5644OneMse)

singleModel5644Mse.head()
# Out:
#    Unnamed: 0  epochs  batch  nodos  layer  learning rate       mse      rmse
# 0           0      10     64     16      1          0.002  0.018697  0.062606
# 1           1      10     64     16      2          0.002  0.018120  0.066166
# 2           2      10     64     16      4          0.002  0.018341  0.071367
# 3           3      10     64     16      8          0.002  0.019180  0.070360
# 4           4      10     64     32      1          0.002  0.018387  0.062395

# %%
singleModel5644Acc
# Out:
#      Unnamed: 0  epochs  batch  nodos  layer  learning rate  keras_loss_model  \
# 0             0      10     64     16      1         0.0020          0.006018
# 1             1      10     64     16      2         0.0020          0.006918
# 2             2      10     64     16      4         0.0020          0.008236
# 3             3      10     64     16      8         0.0020          0.007953
# 4             4      10     64     32      1         0.0020          0.006152
# ..          ...     ...    ...    ...    ...            ...               ...
# 175         175     100    256     32      8         0.0005          0.009040
# 176         176     100    256     64      1         0.0005          0.006514
# 177         177     100    256     64      2         0.0005          0.006688
# 178         178     100    256     64      4         0.0005          0.007698
# 179         179     100    256     64      8         0.0005          0.008748
#
#      keras_model_acc
# 0           0.055883
# 1           0.058685
# 2           0.062746
# 3           0.061080
# 4           0.054747
# ..               ...
# 175         0.070579
# 176         0.057830
# 177         0.062094
# 178         0.067300
# 179         0.072099
#
# [540 rows x 8 columns]

# %%
singleModel5644Mse.columns.values.tolist()
# Out:
# ['Unnamed: 0',
#  'epochs',
#  'batch',
#  'nodos',
#  'layer',
#  'learning rate',
#  'mse',
#  'rmse']

# %%
features_acc = ['epochs', 'batch', 'nodos', 'layer', 'learning rate', 'keras_loss_model', 'keras_model_acc']
singleModel5644Acc = singleModel5644Acc[features_acc]

# %%
features_mse = ['epochs', 'batch', 'nodos', 'layer', 'learning rate', 'mse', 'rmse']
singleModel5644Mse = singleModel5644Mse[features_mse]

# %%
singleModel5644Mse.to_csv('transformed_data/memory_data/model5644-6-0-1-rmse_LSTM.csv', encoding='utf-8')

# %%
idxMse = pd.MultiIndex.from_frame (singleModel5644Mse)
idxAcc = pd.MultiIndex.from_frame (singleModel5644Acc)

# %%
idxMse
# Out:
# MultiIndex([( 10,  64, 16, 1,  0.002, 0.0186965093016624, 0.0626057535409927),
#             ( 10,  64, 16, 2,  0.002, 0.0181203205138444, 0.0661662220954895),
#             ( 10,  64, 16, 4,  0.002, 0.0183412302285432, 0.0713674798607826),
#             ( 10,  64, 16, 8,  0.002, 0.0191795472055673, 0.0703599154949188),
#             ( 10,  64, 32, 1,  0.002, 0.0183869693428277, 0.0623953305184841),
#             ( 10,  64, 32, 2,  0.002, 0.0199045408517122,  0.061934445053339),
#             ( 10,  64, 32, 4,  0.002, 0.0193804446607828, 0.0664038360118866),
#             ( 10,  64, 32, 8,  0.002, 0.0186342075467109, 0.0641467124223709),
#             ( 10,  64, 64, 1,  0.002, 0.0198362059891223, 0.0623822696506977),
#             ( 10,  64, 64, 2,  0.002, 0.0204812716692686, 0.0661772266030311),
#             ...
#             (100, 256, 16, 4, 0.0005, 0.0177163425832986, 0.0727292299270629),
#             (100, 256, 16, 8, 0.0005, 0.0176350194960832, 0.0749840214848518),
#             (100, 256, 32, 1, 0.0005, 0.0187702663242816, 0.0654823705554008),
#             (100, 256, 32, 2, 0.0005, 0.0185402948409318, 0.0671420022845268),
#             (100, 256, 32, 4, 0.0005, 0.0179464872926473, 0.0723764523863792),
#             (100, 256, 32, 8, 0.0005, 0.0181507710367441, 0.0753048658370971),
#             (100, 256, 64, 1, 0.0005,  0.018940744921565, 0.0646915361285209),
#             (100, 256, 64, 2, 0.0005, 0.0194447748363018, 0.0683242231607437),
#             (100, 256, 64, 4, 0.0005, 0.0188363473862409, 0.0732328668236732),
#             (100, 256, 64, 8, 0.0005, 0.0186358243227005, 0.0781517550349235)],
#            names=['epochs', 'batch', 'nodos', 'layer', 'learning rate', 'mse', 'rmse'], length=540)

# %%
idxMse.min()
# Out:
# (10, 64, 16, 1, 0.0005, 0.0187803488224744, 0.0680186301469802)

# %%
singleModel5644Mse[singleModel5644Mse['rmse'] < 0.053795]
# Out:
#      epochs  batch  nodos  layer  learning rate       mse      rmse
# 111      75     64     16      8         0.0020  0.021589  0.053321
# 143      75    256     64      8         0.0020  0.020348  0.053791
# 158     100    128     16      4         0.0020  0.021749  0.053253
# 166     100    128     64      4         0.0020  0.021423  0.053583
# 115      75     64     32      8         0.0010  0.021451  0.053691
# 147     100     64     16      8         0.0010  0.021616  0.053791
# 150     100     64     32      4         0.0010  0.021869  0.053775
# 151     100     64     32      8         0.0010  0.021247  0.053599
# 155     100     64     64      8         0.0005  0.021410  0.053685

# %%
tabla1 = singleModel5644Mse[singleModel5644Mse['rmse'] < 0.053795]

# %%
tabla1.to_excel("transformed_data/tablas/model5644-6-0-1-rmse_LSTM_min.xlsx")

# %%
idxMse.max()
# Out:
# (100, 256, 64, 8, 0.002, 0.0212869960814714, 0.0541525594890117)

# %%
singleModel5644Mse[singleModel5644Mse['rmse'] > 0.125]
# Out:
#     epochs  batch  nodos  layer  learning rate       mse      rmse
# 27      10    256     16      8         0.0010  0.017513  0.129072
# 24      10    256     16      1         0.0005  0.034779  0.191100
# 25      10    256     16      2         0.0005  0.022157  0.152308
# 26      10    256     16      4         0.0005  0.020068  0.139963
# 27      10    256     16      8         0.0005  0.019246  0.138501
# 28      10    256     32      1         0.0005  0.021299  0.145229
# 31      10    256     32      8         0.0005  0.019016  0.136905

# %%
tabla2 = singleModel5644Mse[singleModel5644Mse['rmse'] > 0.125]

# %%
tabla2.to_excel("transformed_data/tablas/model5644-6-0-1-rmse_LSTM_max.xlsx")

# %%
singleModel5644Mse['rmse'].mean()
# Out:
# 0.06553138038488446

# %% [markdown]
# ## Datos LSTM Model 5644 - GRU 6-0-1

# %%
#OK
singleModel5644AccGRU = pd.DataFrame({})
singleModel5644MseGRU = pd.DataFrame({})
for index in range(0,3):
    singleModel5644OneAccGRU = pd.read_csv('transformed_data/model5644-6-0-1-acc_GRU_'+str(index).zfill(1) +'.csv')
    singleModel5644OneMseGRU = pd.read_csv('transformed_data/model5644-6-0-1-mse_GRU_'+str(index).zfill(1) +'.csv')
    singleModel5644AccGRU = singleModel5644AccGRU.append(singleModel5644OneAccGRU)
    singleModel5644MseGRU = singleModel5644MseGRU.append(singleModel5644OneMseGRU)

singleModel5644MseGRU.head()
# Out:
#    Unnamed: 0  epochs  batch  nodos  layer  learning rate       mse      rmse
# 0           0      10     64     16      1          0.002  0.018882  0.058689
# 1           1      10     64     16      2          0.002  0.020016  0.055978
# 2           2      10     64     16      4          0.002  0.020874  0.056448
# 3           3      10     64     16      8          0.002  0.020778  0.057192
# 4           4      10     64     32      1          0.002  0.018947  0.058409

# %%
singleModel5644AccGRU
# Out:
#      Unnamed: 0  epochs  batch  nodos  layer  learning rate  keras_loss_model  \
# 0             0      10     64     16      1         0.0020          0.005074
# 1             1      10     64     16      2         0.0020          0.004435
# 2             2      10     64     16      4         0.0020          0.004318
# 3             3      10     64     16      8         0.0020          0.004542
# 4             4      10     64     32      1         0.0020          0.004798
# ..          ...     ...    ...    ...    ...            ...               ...
# 175         175     100    256     32      8         0.0005          0.004402
# 176         176     100    256     64      1         0.0005          0.005616
# 177         177     100    256     64      2         0.0005          0.004473
# 178         178     100    256     64      4         0.0005          0.004231
# 179         179     100    256     64      8         0.0005          0.004176
#
#      keras_model_acc
# 0           0.051074
# 1           0.046718
# 2           0.044702
# 3           0.046080
# 4           0.049766
# ..               ...
# 175         0.046116
# 176         0.054459
# 177         0.049816
# 178         0.046932
# 179         0.045434
#
# [540 rows x 8 columns]

# %%
singleModel5644AccGRU.columns.values.tolist()
# Out:
# ['Unnamed: 0',
#  'epochs',
#  'batch',
#  'nodos',
#  'layer',
#  'learning rate',
#  'keras_loss_model',
#  'keras_model_acc']

# %%
features_acc = ['epochs', 'batch', 'nodos', 'layer', 'learning rate', 'keras_loss_model', 'keras_model_acc']
singleModel5644AccGRU = singleModel5644AccGRU[features_acc]

# %%
features_mse = ['epochs', 'batch', 'nodos', 'layer', 'learning rate', 'mse', 'rmse']
singleModel5644MseGRU = singleModel5644MseGRU[features_mse]

# %%
singleModel5644MseGRU.to_csv('transformed_data/memory_data/model5644-6-0-1-mse_GRU.csv', encoding='utf-8')

# %%
idxMseGRU = pd.MultiIndex.from_frame (singleModel5644MseGRU)
idxAccGRU = pd.MultiIndex.from_frame (singleModel5644AccGRU)

# %%
idxMseGRU
# Out:
# MultiIndex([( 10,  64, 16, 1,  0.002, 0.0188820827752351, 0.0586885176599025),
#             ( 10,  64, 16, 2,  0.002, 0.0200156401842832, 0.0559783428907394),
#             ( 10,  64, 16, 4,  0.002, 0.0208739601075649, 0.0564483478665351),
#             ( 10,  64, 16, 8,  0.002, 0.0207782946527004, 0.0571924671530723),
#             ( 10,  64, 32, 1,  0.002, 0.0189466886222362, 0.0584093816578388),
#             ( 10,  64, 32, 2,  0.002, 0.0205863062292337, 0.0562663190066814),
#             ( 10,  64, 32, 4,  0.002, 0.0212275758385658,  0.056032694876194),
#             ( 10,  64, 32, 8,  0.002,  0.019779410213232, 0.0550544410943985),
#             ( 10,  64, 64, 1,  0.002, 0.0204650145024061, 0.0590194165706634),
#             ( 10,  64, 64, 2,  0.002, 0.0218835212290287, 0.0554959364235401),
#             ...
#             (100, 256, 16, 4, 0.0005, 0.0186722613871097, 0.0637999102473259),
#             (100, 256, 16, 8, 0.0005,  0.018360523506999, 0.0716722831130027),
#             (100, 256, 32, 1, 0.0005, 0.0190884955227375, 0.0615114569664001),
#             (100, 256, 32, 2, 0.0005, 0.0195379052311182, 0.0582738034427166),
#             (100, 256, 32, 4, 0.0005, 0.0212414301931858, 0.0581951960921287),
#             (100, 256, 32, 8, 0.0005, 0.0216284338384866, 0.0590498819947242),
#             (100, 256, 64, 1, 0.0005, 0.0189744662493467, 0.0619853623211383),
#             (100, 256, 64, 2, 0.0005, 0.0208619553595781, 0.0573486611247062),
#             (100, 256, 64, 4, 0.0005, 0.0218288339674472, 0.0577785372734069),
#             (100, 256, 64, 8, 0.0005, 0.0218788832426071, 0.0577138811349868)],
#            names=['epochs', 'batch', 'nodos', 'layer', 'learning rate', 'mse', 'rmse'], length=540)

# %%
idxMseGRU.min()
# Out:
# (10, 64, 16, 1, 0.0005, 0.0190242435783147, 0.0638016313314437)

# %%
singleModel5644MseGRU[singleModel5644MseGRU['rmse'] < 0.0543]
# Out:
#      epochs  batch  nodos  layer  learning rate       mse      rmse
# 152     100     64     64      1         0.0020  0.021447  0.053698
# 159     100    128     16      8         0.0020  0.020867  0.054078
# 167     100    128     64      8         0.0020  0.021108  0.053877
# 147     100     64     16      8         0.0010  0.021159  0.054154
# 149     100     64     32      2         0.0010  0.021869  0.054138
# 153     100     64     64      2         0.0010  0.021526  0.054296
# 147     100     64     16      8         0.0005  0.021408  0.054285
# 151     100     64     32      8         0.0005  0.021784  0.054294

# %%
tabla1 = singleModel5644MseGRU[singleModel5644MseGRU['rmse'] < 0.0543]

# %%
tabla1.to_excel("transformed_data/tablas/model5644-6-0-1-rmse_GRU_min.xlsx")

# %%
idxMseGRU.max()
# Out:
# (100, 256, 64, 8, 0.002, 0.0209329016506671, 0.0555675402283668)

# %%
singleModel5644MseGRU[singleModel5644MseGRU['rmse'] > 0.095]
# Out:
#     epochs  batch  nodos  layer  learning rate       mse      rmse
# 24      10    256     16      1         0.0010  0.017316  0.112268
# 12      10    128     16      1         0.0005  0.016601  0.097855
# 24      10    256     16      1         0.0005  0.032470  0.180915
# 25      10    256     16      2         0.0005  0.019842  0.127347
# 26      10    256     16      4         0.0005  0.019005  0.128452
# 27      10    256     16      8         0.0005  0.019217  0.134106
# 28      10    256     32      1         0.0005  0.019746  0.137384

# %%
tabla2 = singleModel5644MseGRU[singleModel5644MseGRU['rmse'] > 0.095]

# %%
tabla2.to_excel("transformed_data/tablas/model5644-6-0-1-rmse_GRU_max.xlsx")

# %%
singleModel5644MseGRU['rmse'].mean()
# Out:
# 0.060694710179059544

# %% [markdown]
# ## Datos LSTM TRPW Model 5644 (no separarados) 6-0-1

# %%
#OK
singleModel5644TRPWAcc = pd.DataFrame({})
singleModel5644TRPWMse = pd.DataFrame({})
for index in range(0,3):
    singleModel5644OneTRPWAcc = pd.read_csv('transformed_data/model5644multi-6-0-1-TRPW-acc_'+str(index).zfill(1) +'.csv')
    singleModel5644OneTRPWMse = pd.read_csv('transformed_data/model5644multi-6-0-1-TRPW-mse_'+str(index).zfill(1) +'.csv')
    singleModel5644TRPWAcc = singleModel5644TRPWAcc.append(singleModel5644OneTRPWAcc)
    singleModel5644TRPWMse = singleModel5644TRPWMse.append(singleModel5644OneTRPWMse)

singleModel5644TRPWMse.head()
# Out:
#    Unnamed: 0  epochs  batch  nodos  layer  learning rate       mse      rmse
# 0           0      10     64     16      1          0.002  0.018776  0.063024
# 1           1      10     64     16      2          0.002  0.018234  0.065160
# 2           2      10     64     16      4          0.002  0.019098  0.070034
# 3           3      10     64     16      8          0.002  0.018589  0.071876
# 4           4      10     64     32      1          0.002  0.018591  0.060683

# %%
singleModel5644TRPWAcc
# Out:
#      Unnamed: 0  epochs  batch  nodos  layer  learning rate  keras_loss_model  \
# 0             0      10     64     16      1         0.0020          0.006123
# 1             1      10     64     16      2         0.0020          0.006689
# 2             2      10     64     16      4         0.0020          0.007622
# 3             3      10     64     16      8         0.0020          0.008328
# 4             4      10     64     32      1         0.0020          0.005630
# ..          ...     ...    ...    ...    ...            ...               ...
# 175         175     100    256     32      8         0.0005          0.009301
# 176         176     100    256     64      1         0.0005          0.006328
# 177         177     100    256     64      2         0.0005          0.006803
# 178         178     100    256     64      4         0.0005          0.007860
# 179         179     100    256     64      8         0.0005          0.008833
#
#      keras_model_acc
# 0           0.056058
# 1           0.057830
# 2           0.059681
# 3           0.063231
# 4           0.053542
# ..               ...
# 175         0.072635
# 176         0.056989
# 177         0.062620
# 178         0.068264
# 179         0.072413
#
# [540 rows x 8 columns]

# %%
singleModel5644TRPWMse.columns.values.tolist()
# Out:
# ['Unnamed: 0',
#  'epochs',
#  'batch',
#  'nodos',
#  'layer',
#  'learning rate',
#  'mse',
#  'rmse']

# %%
features_acc = ['epochs', 'batch', 'nodos', 'layer', 'learning rate', 'keras_loss_model', 'keras_model_acc']
singleModel5644TRPWAcc[features_acc]
# Out:
#      epochs  batch  nodos  layer  learning rate  keras_loss_model  \
# 0        10     64     16      1         0.0020          0.006123
# 1        10     64     16      2         0.0020          0.006689
# 2        10     64     16      4         0.0020          0.007622
# 3        10     64     16      8         0.0020          0.008328
# 4        10     64     32      1         0.0020          0.005630
# ..      ...    ...    ...    ...            ...               ...
# 175     100    256     32      8         0.0005          0.009301
# 176     100    256     64      1         0.0005          0.006328
# 177     100    256     64      2         0.0005          0.006803
# 178     100    256     64      4         0.0005          0.007860
# 179     100    256     64      8         0.0005          0.008833
#
#      keras_model_acc
# 0           0.056058
# 1           0.057830
# 2           0.059681
# 3           0.063231
# 4           0.053542
# ..               ...
# 175         0.072635
# 176         0.056989
# 177         0.062620
# 178         0.068264
# 179         0.072413
#
# [540 rows x 7 columns]

# %%
features_mse = ['epochs', 'batch', 'nodos', 'layer', 'learning rate', 'mse', 'rmse']
singleModel5644TRPWMse[features_mse]
# Out:
#      epochs  batch  nodos  layer  learning rate       mse      rmse
# 0        10     64     16      1         0.0020  0.018776  0.063024
# 1        10     64     16      2         0.0020  0.018234  0.065160
# 2        10     64     16      4         0.0020  0.019098  0.070034
# 3        10     64     16      8         0.0020  0.018589  0.071876
# 4        10     64     32      1         0.0020  0.018591  0.060683
# ..      ...    ...    ...    ...            ...       ...       ...
# 175     100    256     32      8         0.0005  0.018018  0.077087
# 176     100    256     64      1         0.0005  0.018964  0.063894
# 177     100    256     64      2         0.0005  0.019378  0.068734
# 178     100    256     64      4         0.0005  0.018965  0.074315
# 179     100    256     64      8         0.0005  0.018608  0.078318
#
# [540 rows x 7 columns]

# %%
singleModel5644TRPWMse.to_csv('transformed_data/memory_data/model5644multi-6-0-1-TRPW-mse_LSTM.csv', encoding='utf-8')

# %%
idxMse = pd.MultiIndex.from_frame (singleModel5644TRPWMse)
idxAcc = pd.MultiIndex.from_frame (singleModel5644TRPWAcc)

# %%
idxMse
# Out:
# MultiIndex([(  0,  10,  64, 16, 1,  0.002, 0.0187756214290857, ...),
#             (  1,  10,  64, 16, 2,  0.002, 0.0182340592145919, ...),
#             (  2,  10,  64, 16, 4,  0.002, 0.0190976820886135, ...),
#             (  3,  10,  64, 16, 8,  0.002, 0.0185889657586812, ...),
#             (  4,  10,  64, 32, 1,  0.002, 0.0185910183936357, ...),
#             (  5,  10,  64, 32, 2,  0.002, 0.0187742561101913, ...),
#             (  6,  10,  64, 32, 4,  0.002, 0.0194572620093822, ...),
#             (  7,  10,  64, 32, 8,  0.002, 0.0189623907208442, ...),
#             (  8,  10,  64, 64, 1,  0.002, 0.0195372067391872, ...),
#             (  9,  10,  64, 64, 2,  0.002, 0.0198068805038929, ...),
#             ...
#             (170, 100, 256, 16, 4, 0.0005, 0.0176983680576086, ...),
#             (171, 100, 256, 16, 8, 0.0005, 0.0176999233663082, ...),
#             (172, 100, 256, 32, 1, 0.0005, 0.0188943408429622, ...),
#             (173, 100, 256, 32, 2, 0.0005, 0.0185436364263296, ...),
#             (174, 100, 256, 32, 4, 0.0005, 0.0179891884326934, ...),
#             (175, 100, 256, 32, 8, 0.0005, 0.0180181954056024, ...),
#             (176, 100, 256, 64, 1, 0.0005, 0.0189641807228326, ...),
#             (177, 100, 256, 64, 2, 0.0005, 0.0193781834095716, ...),
#             (178, 100, 256, 64, 4, 0.0005, 0.0189647432416677, ...),
#             (179, 100, 256, 64, 8, 0.0005, 0.0186076238751411, ...)],
#            names=['Unnamed: 0', 'epochs', 'batch', 'nodos', 'layer', 'learning rate', 'mse', 'rmse'], length=540)

# %%
idxMse.min()
# Out:
# (0, 10, 64, 16, 1, 0.0005, 0.0188334751874208, 0.0688131228089332)

# %%
singleModel5644TRPWMse[singleModel5644TRPWMse['rmse'] < 0.0536]
# Out:
#      Unnamed: 0  epochs  batch  nodos  layer  learning rate       mse  \
# 147         147     100     64     16      8          0.002  0.021192
# 163         163     100    128     32      8          0.002  0.021312
# 166         166     100    128     64      4          0.002  0.021409
# 115         115      75     64     32      8          0.001  0.021575
# 131         131      75    128     64      8          0.001  0.020814
# 151         151     100     64     32      8          0.001  0.021367
# 155         155     100     64     64      8          0.001  0.021056
# 167         167     100    128     64      8          0.001  0.021414
#
#          rmse
# 147  0.053382
# 163  0.053472
# 166  0.053579
# 115  0.053401
# 131  0.053422
# 151  0.053229
# 155  0.053599
# 167  0.053410

# %%
tabla1 = singleModel5644TRPWMse[singleModel5644TRPWMse['rmse'] < 0.0536]

# %%
tabla1.to_excel("transformed_data/tablas/model5644multi-6-0-1-TRPW-rmse_LSTM_min.xlsx")

# %%
idxMse.max()
# Out:
# (179, 100, 256, 64, 8, 0.002, 0.0212625097483396, 0.0546790920197963)

# %%
singleModel5644TRPWMse[singleModel5644TRPWMse['rmse'] > 0.12]
# Out:
#     Unnamed: 0  epochs  batch  nodos  layer  learning rate       mse      rmse
# 24          24      10    256     16      1         0.0010  0.018373  0.121186
# 24          24      10    256     16      1         0.0005  0.035183  0.194893
# 25          25      10    256     16      2         0.0005  0.022607  0.153326
# 27          27      10    256     16      8         0.0005  0.019142  0.137970
# 28          28      10    256     32      1         0.0005  0.020164  0.138463
# 30          30      10    256     32      4         0.0005  0.017795  0.122077
# 31          31      10    256     32      8         0.0005  0.019032  0.137056

# %%
tabla2 = singleModel5644TRPWMse[singleModel5644TRPWMse['rmse'] > 0.12]

# %%
tabla2.to_excel("transformed_data/tablas/model5644multi-6-0-1-TRPW-rmse_LSTM_max.xlsx")

# %%
singleModel5644TRPWMse['rmse'].mean()
# Out:
# 0.06544589222305346

# %% [markdown]
# ## Datos LSTM TRPW Model 5644 (separarados) 6-0-1

# %%
#OK
singleModel5644TRPWAcc = pd.DataFrame({})
singleModel5644TRPWMse = pd.DataFrame({})
for index in range(0,3):
    singleModel5644OneTRPWAcc = pd.read_csv('transformed_data/model5644multi-6-0-1-TRPW-sep-acc_'+str(index).zfill(1) +'.csv')
    singleModel5644OneTRPWMse = pd.read_csv('transformed_data/model5644multi-6-0-1-TRPW-sep-mse_'+str(index).zfill(1) +'.csv')
    singleModel5644TRPWAcc = singleModel5644TRPWAcc.append(singleModel5644OneTRPWAcc)
    singleModel5644TRPWMse = singleModel5644TRPWMse.append(singleModel5644OneTRPWMse)

singleModel5644TRPWMse.head()
# Out:
#    Unnamed: 0  epochs  batch  nodos  layer  learning rate       mse      rmse
# 0           0      10     64     16      1          0.002  0.018911  0.063114
# 1           1      10     64     16      2          0.002  0.018138  0.065198
# 2           2      10     64     16      4          0.002  0.018546  0.070529
# 3           3      10     64     16      8          0.002  0.019593  0.069270
# 4           4      10     64     32      1          0.002  0.018432  0.062560

# %%
singleModel5644TRPWAcc
# Out:
#      Unnamed: 0  epochs  batch  nodos  layer  learning rate  keras_loss_model  \
# 0             0      10     64     16      1         0.0020          0.006111
# 1             1      10     64     16      2         0.0020          0.006687
# 2             2      10     64     16      4         0.0020          0.008080
# 3             3      10     64     16      8         0.0020          0.007820
# 4             4      10     64     32      1         0.0020          0.006198
# ..          ...     ...    ...    ...    ...            ...               ...
# 175         175     100    256     32      8         0.0005          0.009213
# 176         176     100    256     64      1         0.0005          0.006544
# 177         177     100    256     64      2         0.0005          0.006625
# 178         178     100    256     64      4         0.0005          0.007885
# 179         179     100    256     64      8         0.0005          0.008588
#
#      keras_model_acc
# 0           0.056043
# 1           0.057245
# 2           0.062196
# 3           0.060629
# 4           0.054791
# ..               ...
# 175         0.072205
# 176         0.057788
# 177         0.061342
# 178         0.068221
# 179         0.071122
#
# [540 rows x 8 columns]

# %%
singleModel5644TRPWMse.columns.values.tolist()
# Out:
# ['Unnamed: 0',
#  'epochs',
#  'batch',
#  'nodos',
#  'layer',
#  'learning rate',
#  'mse',
#  'rmse']

# %%
features_acc = ['epochs', 'batch', 'nodos', 'layer', 'learning rate', 'keras_loss_model', 'keras_model_acc']
singleModel5644TRPWAcc[features_acc]
# Out:
#      epochs  batch  nodos  layer  learning rate  keras_loss_model  \
# 0        10     64     16      1         0.0020          0.006111
# 1        10     64     16      2         0.0020          0.006687
# 2        10     64     16      4         0.0020          0.008080
# 3        10     64     16      8         0.0020          0.007820
# 4        10     64     32      1         0.0020          0.006198
# ..      ...    ...    ...    ...            ...               ...
# 175     100    256     32      8         0.0005          0.009213
# 176     100    256     64      1         0.0005          0.006544
# 177     100    256     64      2         0.0005          0.006625
# 178     100    256     64      4         0.0005          0.007885
# 179     100    256     64      8         0.0005          0.008588
#
#      keras_model_acc
# 0           0.056043
# 1           0.057245
# 2           0.062196
# 3           0.060629
# 4           0.054791
# ..               ...
# 175         0.072205
# 176         0.057788
# 177         0.061342
# 178         0.068221
# 179         0.071122
#
# [540 rows x 7 columns]

# %%
features_mse = ['epochs', 'batch', 'nodos', 'layer', 'learning rate', 'mse', 'rmse']
singleModel5644TRPWMse[features_mse]
# Out:
#      epochs  batch  nodos  layer  learning rate       mse      rmse
# 0        10     64     16      1         0.0020  0.018911  0.063114
# 1        10     64     16      2         0.0020  0.018138  0.065198
# 2        10     64     16      4         0.0020  0.018546  0.070529
# 3        10     64     16      8         0.0020  0.019593  0.069270
# 4        10     64     32      1         0.0020  0.018432  0.062560
# ..      ...    ...    ...    ...            ...       ...       ...
# 175     100    256     32      8         0.0005  0.018003  0.076823
# 176     100    256     64      1         0.0005  0.018895  0.064646
# 177     100    256     64      2         0.0005  0.019253  0.067573
# 178     100    256     64      4         0.0005  0.018881  0.074142
# 179     100    256     64      8         0.0005  0.018755  0.077392
#
# [540 rows x 7 columns]

# %%
singleModel5644TRPWMse.to_csv('transformed_data/memory_data/model5644multi-6-0-1-TRPW-sep-mse_LSTM.csv', encoding='utf-8')

# %%
idxMse = pd.MultiIndex.from_frame (singleModel5644TRPWMse)
idxAcc = pd.MultiIndex.from_frame (singleModel5644TRPWAcc)

# %%
idxMse
# Out:
# MultiIndex([(  0,  10,  64, 16, 1,  0.002, 0.0189106706529855, ...),
#             (  1,  10,  64, 16, 2,  0.002, 0.0181383434683084, ...),
#             (  2,  10,  64, 16, 4,  0.002, 0.0185455530881881, ...),
#             (  3,  10,  64, 16, 8,  0.002, 0.0195934735238552, ...),
#             (  4,  10,  64, 32, 1,  0.002,  0.018431993201375, ...),
#             (  5,  10,  64, 32, 2,  0.002,  0.019381383433938, ...),
#             (  6,  10,  64, 32, 4,  0.002, 0.0196696035563945, ...),
#             (  7,  10,  64, 32, 8,  0.002, 0.0181898195296525, ...),
#             (  8,  10,  64, 64, 1,  0.002, 0.0207547415047884, ...),
#             (  9,  10,  64, 64, 2,  0.002, 0.0212687756866216, ...),
#             ...
#             (170, 100, 256, 16, 4, 0.0005, 0.0177891850471496, ...),
#             (171, 100, 256, 16, 8, 0.0005, 0.0173898823559284, ...),
#             (172, 100, 256, 32, 1, 0.0005, 0.0188082717359066, ...),
#             (173, 100, 256, 32, 2, 0.0005, 0.0186314061284065, ...),
#             (174, 100, 256, 32, 4, 0.0005, 0.0181628931313753, ...),
#             (175, 100, 256, 32, 8, 0.0005, 0.0180031713098287, ...),
#             (176, 100, 256, 64, 1, 0.0005, 0.0188953075557947, ...),
#             (177, 100, 256, 64, 2, 0.0005, 0.0192525386810302, ...),
#             (178, 100, 256, 64, 4, 0.0005, 0.0188806150108575, ...),
#             (179, 100, 256, 64, 8, 0.0005, 0.0187552310526371, ...)],
#            names=['Unnamed: 0', 'epochs', 'batch', 'nodos', 'layer', 'learning rate', 'mse', 'rmse'], length=540)

# %%
idxMse.min()
# Out:
# (0, 10, 64, 16, 1, 0.0005, 0.0186844691634178, 0.0688117370009422)

# %%
singleModel5644TRPWMse[singleModel5644TRPWMse['rmse'] < 0.05373]
# Out:
#      Unnamed: 0  epochs  batch  nodos  layer  learning rate       mse  \
# 146         146     100     64     16      4          0.002  0.021649
# 147         147     100     64     16      8          0.002  0.021215
# 151         151     100     64     32      8          0.002  0.020933
# 166         166     100    128     64      4          0.002  0.021385
# 115         115      75     64     32      8          0.001  0.021306
# 131         131      75    128     64      8          0.001  0.020866
# 150         150     100     64     32      4          0.001  0.021854
# 151         151     100     64     32      8          0.001  0.021421
#
#          rmse
# 146  0.053619
# 147  0.053540
# 151  0.053729
# 166  0.053318
# 115  0.053536
# 131  0.053409
# 150  0.053382
# 151  0.053546

# %%
tabla1 = singleModel5644TRPWMse[singleModel5644TRPWMse['rmse'] < 0.05373]

# %%
tabla1.to_excel("transformed_data/tablas/model5644multi-6-0-1-TRPW-sep-rmse_LSTM_min.xlsx")

# %%
idxMse.max()
# Out:
# (179, 100, 256, 64, 8, 0.002, 0.0210363566875457, 0.0546847470104694)

# %%
singleModel5644TRPWMse[singleModel5644TRPWMse['rmse'] > 0.13]
# Out:
#     Unnamed: 0  epochs  batch  nodos  layer  learning rate       mse      rmse
# 27          27      10    256     16      8         0.0010  0.017916  0.130963
# 24          24      10    256     16      1         0.0005  0.036459  0.198453
# 25          25      10    256     16      2         0.0005  0.021319  0.145936
# 26          26      10    256     16      4         0.0005  0.019884  0.139953
# 27          27      10    256     16      8         0.0005  0.019251  0.138587
# 28          28      10    256     32      1         0.0005  0.021095  0.143298
# 31          31      10    256     32      8         0.0005  0.019040  0.137020

# %%
tabla2 = singleModel5644TRPWMse[singleModel5644TRPWMse['rmse'] > 0.13]

# %%
tabla2.to_excel("transformed_data/tablas/model5644multi-6-0-1-TRPW-sep-rmse_LSTM_max.xlsx")

# %%
singleModel5644TRPWMse['rmse'].mean()
# Out:
# 0.06569762338918662

# %% [markdown]
# ## Datos GRU TRPW Model 5644 (no separarados) 6-0-1

# %%
#OK
singleModel5644TRPWAcc = pd.DataFrame({})
singleModel5644TRPWMse = pd.DataFrame({})
for index in range(0,3):
    singleModel5644OneTRPWAcc = pd.read_csv('transformed_data/model5644multi-6-0-1-TRPW-acc_GRU_'+str(index).zfill(1) +'.csv')
    singleModel5644OneTRPWMse = pd.read_csv('transformed_data/model5644multi-6-0-1-TRPW-mse_GRU_'+str(index).zfill(1) +'.csv')
    singleModel5644TRPWAcc = singleModel5644TRPWAcc.append(singleModel5644OneTRPWAcc)
    singleModel5644TRPWMse = singleModel5644TRPWMse.append(singleModel5644OneTRPWMse)

singleModel5644TRPWMse.head()
# Out:
#    Unnamed: 0  epochs  batch  nodos  layer  learning rate       mse      rmse
# 0           0      10     64     16      1          0.002  0.018941  0.060746
# 1           1      10     64     16      2          0.002  0.018528  0.059288
# 2           2      10     64     16      4          0.002  0.020809  0.055657
# 3           3      10     64     16      8          0.002  0.020911  0.057614
# 4           4      10     64     32      1          0.002  0.019046  0.058001

# %%
singleModel5644TRPWMse
# Out:
#      Unnamed: 0  epochs  batch  nodos  layer  learning rate       mse  \
# 0             0      10     64     16      1         0.0020  0.018941
# 1             1      10     64     16      2         0.0020  0.018528
# 2             2      10     64     16      4         0.0020  0.020809
# 3             3      10     64     16      8         0.0020  0.020911
# 4             4      10     64     32      1         0.0020  0.019046
# ..          ...     ...    ...    ...    ...            ...       ...
# 175         175     100    256     32      8         0.0005  0.021760
# 176         176     100    256     64      1         0.0005  0.019124
# 177         177     100    256     64      2         0.0005  0.020947
# 178         178     100    256     64      4         0.0005  0.021790
# 179         179     100    256     64      8         0.0005  0.021943
#
#          rmse
# 0    0.060746
# 1    0.059288
# 2    0.055657
# 3    0.057614
# 4    0.058001
# ..        ...
# 175  0.059245
# 176  0.059982
# 177  0.056516
# 178  0.057201
# 179  0.057989
#
# [540 rows x 8 columns]

# %%
singleModel5644TRPWAcc
# Out:
#      Unnamed: 0  epochs  batch  nodos  layer  learning rate  keras_loss_model  \
# 0             0      10     64     16      1         0.0020          0.005435
# 1             1      10     64     16      2         0.0020          0.004977
# 2             2      10     64     16      4         0.0020          0.004297
# 3             3      10     64     16      8         0.0020          0.004593
# 4             4      10     64     32      1         0.0020          0.004741
# ..          ...     ...    ...    ...    ...            ...               ...
# 175         175     100    256     32      8         0.0005          0.004420
# 176         176     100    256     64      1         0.0005          0.005264
# 177         177     100    256     64      2         0.0005          0.004345
# 178         178     100    256     64      4         0.0005          0.004193
# 179         179     100    256     64      8         0.0005          0.004198
#
#      keras_model_acc
# 0           0.053167
# 1           0.050375
# 2           0.044721
# 3           0.046752
# 4           0.049131
# ..               ...
# 175         0.045935
# 176         0.052553
# 177         0.048320
# 178         0.046420
# 179         0.045691
#
# [540 rows x 8 columns]

# %%
singleModel5644TRPWMse.columns.values.tolist()
# Out:
# ['Unnamed: 0',
#  'epochs',
#  'batch',
#  'nodos',
#  'layer',
#  'learning rate',
#  'mse',
#  'rmse']

# %%
features_acc = ['epochs', 'batch', 'nodos', 'layer', 'learning rate', 'keras_loss_model', 'keras_model_acc']
singleModel5644TRPWAcc = singleModel5644TRPWAcc[features_acc]

# %%
features_mse = ['epochs', 'batch', 'nodos', 'layer', 'learning rate', 'mse', 'rmse']
singleModel5644TRPWMse = singleModel5644TRPWMse[features_mse]

# %%
singleModel5644TRPWMse.to_csv('transformed_data/memory_data/model5644multi-6-0-1-TRPW-mse_GRU.csv', encoding='utf-8')

# %%
idxMse = pd.MultiIndex.from_frame (singleModel5644TRPWMse)
idxAcc = pd.MultiIndex.from_frame (singleModel5644TRPWAcc)

# %%
idxMse
# Out:
# MultiIndex([( 10,  64, 16, 1,  0.002, 0.0189410280436277, 0.0607464239001274),
#             ( 10,  64, 16, 2,  0.002, 0.0185280479490757, 0.0592884086072444),
#             ( 10,  64, 16, 4,  0.002, 0.0208087489008903, 0.0556568764150142),
#             ( 10,  64, 16, 8,  0.002, 0.0209109410643577, 0.0576137937605381),
#             ( 10,  64, 32, 1,  0.002, 0.0190463196486234, 0.0580011308193206),
#             ( 10,  64, 32, 2,  0.002, 0.0211880970746278, 0.0553450807929039),
#             ( 10,  64, 32, 4,  0.002, 0.0213656555861234, 0.0561385005712509),
#             ( 10,  64, 32, 8,  0.002, 0.0199935175478458, 0.0550289191305637),
#             ( 10,  64, 64, 1,  0.002,  0.020778264850378, 0.0584597960114479),
#             ( 10,  64, 64, 2,  0.002, 0.0217097103595733, 0.0558441989123821),
#             ...
#             (100, 256, 16, 4, 0.0005, 0.0194263402372598, 0.0621941685676574),
#             (100, 256, 16, 8, 0.0005, 0.0192192699760198, 0.0683847591280937),
#             (100, 256, 32, 1, 0.0005, 0.0190642867237329, 0.0618782639503479),
#             (100, 256, 32, 2, 0.0005, 0.0192320942878723, 0.0593622922897338),
#             (100, 256, 32, 4, 0.0005, 0.0211604442447423, 0.0567152835428714),
#             (100, 256, 32, 8, 0.0005, 0.0217604786157608, 0.0592451691627502),
#             (100, 256, 64, 1, 0.0005, 0.0191237349063158, 0.0599818713963031),
#             (100, 256, 64, 2, 0.0005, 0.0209468360990285, 0.0565159246325492),
#             (100, 256, 64, 4, 0.0005, 0.0217900648713111, 0.0572013370692729),
#             (100, 256, 64, 8, 0.0005, 0.0219434220343828, 0.0579885616898536)],
#            names=['epochs', 'batch', 'nodos', 'layer', 'learning rate', 'mse', 'rmse'], length=540)

# %%
idxMse.min()
# Out:
# (10, 64, 16, 1, 0.0005, 0.0196069199591875, 0.0647803395986557)

# %%
singleModel5644TRPWMse[singleModel5644TRPWMse['rmse'] < 0.05419]
# Out:
#      epochs  batch  nodos  layer  learning rate       mse      rmse
# 123      75    128     16      8         0.0020  0.022387  0.054017
# 152     100     64     64      1         0.0020  0.021895  0.053812
# 158     100    128     16      4         0.0020  0.021105  0.053814
# 165     100    128     64      2         0.0020  0.021310  0.053924
# 111      75     64     16      8         0.0010  0.022097  0.054120
# 147     100     64     16      8         0.0010  0.021201  0.053879
# 147     100     64     16      8         0.0005  0.021426  0.053519
# 158     100    128     16      4         0.0005  0.021251  0.054184

# %%
tabla1 = singleModel5644TRPWMse[singleModel5644TRPWMse['rmse'] < 0.05419]

# %%
tabla1.to_excel("transformed_data/tablas/model5644multi-6-0-1-TRPW-rmse_GRU_min.xlsx")

# %%
idxMse.max()
# Out:
# (100, 256, 64, 8, 0.002, 0.0208955649286508, 0.056178793311119)

# %%
singleModel5644TRPWMse[singleModel5644TRPWMse['rmse'] > 0.083]
# Out:
#     epochs  batch  nodos  layer  learning rate       mse      rmse
# 27      10    256     16      8         0.0020  0.017654  0.084716
# 24      10    256     16      1         0.0010  0.017401  0.112546
# 12      10    128     16      1         0.0005  0.016786  0.110173
# 24      10    256     16      1         0.0005  0.028387  0.170854
# 25      10    256     16      2         0.0005  0.020482  0.132250
# 26      10    256     16      4         0.0005  0.017090  0.094762
# 28      10    256     32      1         0.0005  0.018015  0.120854

# %%
tabla2 = singleModel5644TRPWMse[singleModel5644TRPWMse['rmse'] > 0.083]

# %%
tabla2.to_excel("transformed_data/tablas/model5644multi-6-0-1-TRPW-rmse_GRU_max.xlsx")

# %%
singleModel5644TRPWMse['rmse'].mean()
# Out:
# 0.06051465702691559

# %% [markdown]
# ## Datos GRU TRPW Model 5644 (separarados) 6-0-1

# %%
#OK
singleModel5644TRPWAcc = pd.DataFrame({})
singleModel5644TRPWMse = pd.DataFrame({})
for index in range(0,3):
    singleModel5644OneTRPWAcc = pd.read_csv('transformed_data/model5644multi-6-0-1-TRPW-sep-acc_GRU_'+str(index).zfill(1) +'.csv')
    singleModel5644OneTRPWMse = pd.read_csv('transformed_data/model5644multi-6-0-1-TRPW-sep-mse_GRU_'+str(index).zfill(1) +'.csv')
    singleModel5644TRPWAcc = singleModel5644TRPWAcc.append(singleModel5644OneTRPWAcc)
    singleModel5644TRPWMse = singleModel5644TRPWMse.append(singleModel5644OneTRPWMse)

singleModel5644TRPWMse.head()
# Out:
#    Unnamed: 0  epochs  batch  nodos  layer  learning rate       mse      rmse
# 0           0      10     64     16      1          0.002  0.019046  0.059762
# 1           1      10     64     16      2          0.002  0.019174  0.056738
# 2           2      10     64     16      4          0.002  0.020741  0.058239
# 3           3      10     64     16      8          0.002  0.019556  0.056309
# 4           4      10     64     32      1          0.002  0.018918  0.058272

# %%
singleModel5644TRPWAcc
# Out:
#      Unnamed: 0  epochs  batch  nodos  layer  learning rate  keras_loss_model  \
# 0             0      10     64     16      1         0.0020          0.005246
# 1             1      10     64     16      2         0.0020          0.004650
# 2             2      10     64     16      4         0.0020          0.004429
# 3             3      10     64     16      8         0.0020          0.005041
# 4             4      10     64     32      1         0.0020          0.004906
# ..          ...     ...    ...    ...    ...            ...               ...
# 175         175     100    256     32      8         0.0005          0.004538
# 176         176     100    256     64      1         0.0005          0.005343
# 177         177     100    256     64      2         0.0005          0.004289
# 178         178     100    256     64      4         0.0005          0.004198
# 179         179     100    256     64      8         0.0005          0.004204
#
#      keras_model_acc
# 0           0.052279
# 1           0.048179
# 2           0.045978
# 3           0.049543
# 4           0.049930
# ..               ...
# 175         0.046510
# 176         0.052736
# 177         0.047646
# 178         0.046467
# 179         0.046719
#
# [540 rows x 8 columns]

# %%
singleModel5644TRPWMse.columns.values.tolist()
# Out:
# ['Unnamed: 0',
#  'epochs',
#  'batch',
#  'nodos',
#  'layer',
#  'learning rate',
#  'mse',
#  'rmse']

# %%
features_acc = ['epochs', 'batch', 'nodos', 'layer', 'learning rate', 'keras_loss_model', 'keras_model_acc']
singleModel5644TRPWAcc = singleModel5644TRPWAcc[features_acc]

# %%
features_mse = ['epochs', 'batch', 'nodos', 'layer', 'learning rate', 'mse', 'rmse']
singleModel5644TRPWMse = singleModel5644TRPWMse[features_mse]

# %%
singleModel5644TRPWMse.to_csv('transformed_data/memory_data/model5644multi-6-0-1-TRPW-sep-mse_GRU.csv', encoding='utf-8')

# %%
idxMse = pd.MultiIndex.from_frame (singleModel5644TRPWMse)
idxAcc = pd.MultiIndex.from_frame (singleModel5644TRPWAcc)

# %%
idxMse
# Out:
# MultiIndex([( 10,  64, 16, 1,  0.002, 0.0190457385033369, 0.0597618706524372),
#             ( 10,  64, 16, 2,  0.002, 0.0191735960543155, 0.0567376464605331),
#             ( 10,  64, 16, 4,  0.002, 0.0207413733005523, 0.0582392327487468),
#             ( 10,  64, 16, 8,  0.002, 0.0195564739406108, 0.0563086904585361),
#             ( 10,  64, 32, 1,  0.002, 0.0189182087779045, 0.0582721605896949),
#             ( 10,  64, 32, 2,  0.002, 0.0210636928677558, 0.0556567646563053),
#             ( 10,  64, 32, 4,  0.002, 0.0211412589997053, 0.0563971884548664),
#             ( 10,  64, 32, 8,  0.002, 0.0200644694268703, 0.0553093068301677),
#             ( 10,  64, 64, 1,  0.002, 0.0203746017068624, 0.0595073848962783),
#             ( 10,  64, 64, 2,  0.002,  0.021631808951497, 0.0560276918113231),
#             ...
#             (100, 256, 16, 4, 0.0005, 0.0196063686162233, 0.0602328069508075),
#             (100, 256, 16, 8, 0.0005,  0.018927851691842, 0.0684925466775894),
#             (100, 256, 32, 1, 0.0005, 0.0190789438784122, 0.0620574653148651),
#             (100, 256, 32, 2, 0.0005, 0.0196399707347154, 0.0583785250782966),
#             (100, 256, 32, 4, 0.0005, 0.0212885234504938, 0.0570652708411216),
#             (100, 256, 32, 8, 0.0005, 0.0216055642813444, 0.0598963163793087),
#             (100, 256, 64, 1, 0.0005, 0.0190113931894302, 0.0603688172996044),
#             (100, 256, 64, 2, 0.0005, 0.0212095938622951, 0.0561406426131725),
#             (100, 256, 64, 4, 0.0005,  0.021876573562622, 0.0574529990553855),
#             (100, 256, 64, 8, 0.0005, 0.0218144301325082, 0.0580341294407844)],
#            names=['epochs', 'batch', 'nodos', 'layer', 'learning rate', 'mse', 'rmse'], length=540)

# %%
idxMse.min()
# Out:
# (10, 64, 16, 1, 0.0005, 0.0194336920976638, 0.0642481967806816)

# %%
singleModel5644TRPWMse[singleModel5644TRPWMse['rmse'] < 0.054225]
# Out:
#      epochs  batch  nodos  layer  learning rate       mse      rmse
# 123      75    128     16      8         0.0020  0.022647  0.054011
# 152     100     64     64      1         0.0020  0.021763  0.053569
# 147     100     64     16      8         0.0010  0.021564  0.053415
# 153     100     64     64      2         0.0010  0.021699  0.054202
# 163     100    128     32      8         0.0010  0.021139  0.053979
# 150     100     64     32      4         0.0005  0.021451  0.054224
# 151     100     64     32      8         0.0005  0.021716  0.054050
# 153     100     64     64      2         0.0005  0.022154  0.054185

# %%
tabla1 = singleModel5644TRPWMse[singleModel5644TRPWMse['rmse'] < 0.054225]

# %%
tabla1.to_excel("transformed_data/tablas/model5644multi-6-0-1-TRPW-sep-rmse_GRU_min.xlsx")

# %%
idxMse.max()
# Out:
# (100, 256, 64, 8, 0.002, 0.0211157947778701, 0.0564119443297386)

# %%
singleModel5644TRPWMse[singleModel5644TRPWMse['rmse'] > 0.09]
# Out:
#     epochs  batch  nodos  layer  learning rate       mse      rmse
# 24      10    256     16      1         0.0010  0.017147  0.108304
# 12      10    128     16      1         0.0005  0.016355  0.096075
# 24      10    256     16      1         0.0005  0.036848  0.190523
# 25      10    256     16      2         0.0005  0.021052  0.141097
# 26      10    256     16      4         0.0005  0.017021  0.099794
# 27      10    256     16      8         0.0005  0.018834  0.125410
# 28      10    256     32      1         0.0005  0.018550  0.124868

# %%
tabla2 = singleModel5644TRPWMse[singleModel5644TRPWMse['rmse'] > 0.09]

# %%
tabla2.to_excel("transformed_data/tablas/model5644multi-6-0-1-TRPW-sep-rmse_GRU_max.xlsx")

# %%
singleModel5644TRPWMse['rmse'].mean()
# Out:
# 0.060624195248992305

# %% [markdown]
# ## Datos LSTM TRPWNN2C Model 5644 (no separarados) 6-0-1

# %%
#OK
singleModel5644TRPWAcc = pd.DataFrame({})
singleModel5644TRPWMse = pd.DataFrame({})
for index in range(0,3):
    singleModel5644OneTRPWAcc = pd.read_csv('transformed_data/model5644multi-6-0-1-TRPWNN2C-acc_'+str(index).zfill(1) +'.csv')
    singleModel5644OneTRPWMse = pd.read_csv('transformed_data/model5644multi-6-0-1-TRPWNN2C-mse_'+str(index).zfill(1) +'.csv')
    singleModel5644TRPWAcc = singleModel5644TRPWAcc.append(singleModel5644OneTRPWAcc)
    singleModel5644TRPWMse = singleModel5644TRPWMse.append(singleModel5644OneTRPWMse)

singleModel5644TRPWMse.head()
# Out:
#    Unnamed: 0  epochs  batch  nodos  layer  learning rate       mse      rmse
# 0           0      10     64     16      1          0.002  0.018697  0.062606
# 1           1      10     64     16      2          0.002  0.018120  0.066166
# 2           2      10     64     16      4          0.002  0.018341  0.071367
# 3           3      10     64     16      8          0.002  0.019180  0.070360
# 4           4      10     64     32      1          0.002  0.018387  0.062395

# %%
singleModel5644TRPWAcc
# Out:
#      Unnamed: 0  epochs  batch  nodos  layer  learning rate  keras_loss_model  \
# 0             0      10     64     16      1         0.0020          0.006018
# 1             1      10     64     16      2         0.0020          0.006918
# 2             2      10     64     16      4         0.0020          0.008236
# 3             3      10     64     16      8         0.0020          0.007953
# 4             4      10     64     32      1         0.0020          0.006152
# ..          ...     ...    ...    ...    ...            ...               ...
# 175         175     100    256     32      8         0.0005          0.009060
# 176         176     100    256     64      1         0.0005          0.006566
# 177         177     100    256     64      2         0.0005          0.006672
# 178         178     100    256     64      4         0.0005          0.007862
# 179         179     100    256     64      8         0.0005          0.008619
#
#      keras_model_acc
# 0           0.055883
# 1           0.058685
# 2           0.062746
# 3           0.061080
# 4           0.054747
# ..               ...
# 175         0.070946
# 176         0.058180
# 177         0.061382
# 178         0.067776
# 179         0.071307
#
# [540 rows x 8 columns]

# %%
singleModel5644TRPWMse.columns.values.tolist()
# Out:
# ['Unnamed: 0',
#  'epochs',
#  'batch',
#  'nodos',
#  'layer',
#  'learning rate',
#  'mse',
#  'rmse']

# %%
features_acc = ['epochs', 'batch', 'nodos', 'layer', 'learning rate', 'keras_loss_model', 'keras_model_acc']
singleModel5644TRPWAcc[features_acc]
# Out:
#      epochs  batch  nodos  layer  learning rate  keras_loss_model  \
# 0        10     64     16      1         0.0020          0.006018
# 1        10     64     16      2         0.0020          0.006918
# 2        10     64     16      4         0.0020          0.008236
# 3        10     64     16      8         0.0020          0.007953
# 4        10     64     32      1         0.0020          0.006152
# ..      ...    ...    ...    ...            ...               ...
# 175     100    256     32      8         0.0005          0.009060
# 176     100    256     64      1         0.0005          0.006566
# 177     100    256     64      2         0.0005          0.006672
# 178     100    256     64      4         0.0005          0.007862
# 179     100    256     64      8         0.0005          0.008619
#
#      keras_model_acc
# 0           0.055883
# 1           0.058685
# 2           0.062746
# 3           0.061080
# 4           0.054747
# ..               ...
# 175         0.070946
# 176         0.058180
# 177         0.061382
# 178         0.067776
# 179         0.071307
#
# [540 rows x 7 columns]

# %%
features_mse = ['epochs', 'batch', 'nodos', 'layer', 'learning rate', 'mse', 'rmse']
singleModel5644TRPWMse[features_mse]
# Out:
#      epochs  batch  nodos  layer  learning rate       mse      rmse
# 0        10     64     16      1         0.0020  0.018697  0.062606
# 1        10     64     16      2         0.0020  0.018120  0.066166
# 2        10     64     16      4         0.0020  0.018341  0.071367
# 3        10     64     16      8         0.0020  0.019180  0.070360
# 4        10     64     32      1         0.0020  0.018387  0.062395
# ..      ...    ...    ...    ...            ...       ...       ...
# 175     100    256     32      8         0.0005  0.018181  0.075731
# 176     100    256     64      1         0.0005  0.019004  0.064961
# 177     100    256     64      2         0.0005  0.019201  0.067511
# 178     100    256     64      4         0.0005  0.018712  0.073614
# 179     100    256     64      8         0.0005  0.018752  0.077684
#
# [540 rows x 7 columns]

# %%
singleModel5644TRPWMse.to_csv('transformed_data/memory_data/model5644multi-6-0-1-TRPWNN2C-mse_LSTM.csv', encoding='utf-8')

# %%
idxMse = pd.MultiIndex.from_frame (singleModel5644TRPWMse)
idxAcc = pd.MultiIndex.from_frame (singleModel5644TRPWAcc)

# %%
idxMse
# Out:
# MultiIndex([(  0,  10,  64, 16, 1,  0.002, 0.0186965093016624, ...),
#             (  1,  10,  64, 16, 2,  0.002, 0.0181203205138444, ...),
#             (  2,  10,  64, 16, 4,  0.002, 0.0183412302285432, ...),
#             (  3,  10,  64, 16, 8,  0.002, 0.0191795527935028, ...),
#             (  4,  10,  64, 32, 1,  0.002, 0.0183869693428277, ...),
#             (  5,  10,  64, 32, 2,  0.002, 0.0199045427143573, ...),
#             (  6,  10,  64, 32, 4,  0.002, 0.0193804427981376, ...),
#             (  7,  10,  64, 32, 8,  0.002, 0.0186342094093561, ...),
#             (  8,  10,  64, 64, 1,  0.002, 0.0198362078517675, ...),
#             (  9,  10,  64, 64, 2,  0.002, 0.0204812716692686, ...),
#             ...
#             (170, 100, 256, 16, 4, 0.0005, 0.0176939740777015, ...),
#             (171, 100, 256, 16, 8, 0.0005, 0.0176130905747413, ...),
#             (172, 100, 256, 32, 1, 0.0005, 0.0188982672989368, ...),
#             (173, 100, 256, 32, 2, 0.0005, 0.0186411626636981, ...),
#             (174, 100, 256, 32, 4, 0.0005, 0.0181723199784755, ...),
#             (175, 100, 256, 32, 8, 0.0005, 0.0181807950139045, ...),
#             (176, 100, 256, 64, 1, 0.0005, 0.0190039575099945, ...),
#             (177, 100, 256, 64, 2, 0.0005, 0.0192013401538133, ...),
#             (178, 100, 256, 64, 4, 0.0005, 0.0187117718160152, ...),
#             (179, 100, 256, 64, 8, 0.0005, 0.0187522210180759, ...)],
#            names=['Unnamed: 0', 'epochs', 'batch', 'nodos', 'layer', 'learning rate', 'mse', 'rmse'], length=540)

# %%
idxMse.min()
# Out:
# (0, 10, 64, 16, 1, 0.0005, 0.0188112799078226, 0.0691038891673088)

# %%
singleModel5644TRPWMse[singleModel5644TRPWMse['rmse'] < 0.0538]
# Out:
#      Unnamed: 0  epochs  batch  nodos  layer  learning rate       mse  \
# 111         111      75     64     16      8          0.002  0.021589
# 143         143      75    256     64      8          0.002  0.020348
# 158         158     100    128     16      4          0.002  0.021749
# 166         166     100    128     64      4          0.002  0.021423
# 131         131      75    128     64      8          0.001  0.020906
# 147         147     100     64     16      8          0.001  0.021722
# 151         151     100     64     32      8          0.001  0.021194
# 167         167     100    128     64      8          0.001  0.021197
#
#          rmse
# 111  0.053321
# 143  0.053791
# 158  0.053253
# 166  0.053583
# 131  0.053374
# 147  0.053645
# 151  0.053296
# 167  0.053798

# %%
tabla1 = singleModel5644TRPWMse[singleModel5644TRPWMse['rmse'] < 0.0538]

# %%
tabla1.to_excel("transformed_data/tablas/model5644multi-6-0-1-TRPWNN2C-rmse_LSTM_min.xlsx")

# %%
idxMse.max()
# Out:
# (179, 100, 256, 64, 8, 0.002, 0.0212869998067617, 0.0541525594890117)

# %%
singleModel5644TRPWMse[singleModel5644TRPWMse['rmse'] > 0.13]
# Out:
#     Unnamed: 0  epochs  batch  nodos  layer  learning rate       mse      rmse
# 27          27      10    256     16      8         0.0010  0.019062  0.137799
# 24          24      10    256     16      1         0.0005  0.037532  0.199826
# 25          25      10    256     16      2         0.0005  0.022885  0.154481
# 26          26      10    256     16      4         0.0005  0.019766  0.139590
# 27          27      10    256     16      8         0.0005  0.019549  0.139793
# 28          28      10    256     32      1         0.0005  0.019906  0.135677
# 31          31      10    256     32      8         0.0005  0.019005  0.137005

# %%
tabla2 = singleModel5644TRPWMse[singleModel5644TRPWMse['rmse'] > 0.13]

# %%
tabla2.to_excel("transformed_data/tablas/model5644multi-6-0-1-TRPWNN2C-rmse_LSTM_max.xlsx")

# %%
singleModel5644TRPWMse['rmse'].mean()
# Out:
# 0.06559283260118073

# %% [markdown]
# ## Datos LSTM TRPW Model 5644 (separarados) 6-0-1

# %%
#OK
singleModel5644TRPWAcc = pd.DataFrame({})
singleModel5644TRPWMse = pd.DataFrame({})
for index in range(0,3):
    singleModel5644OneTRPWAcc = pd.read_csv('transformed_data/model5644multi-6-0-1-TRPWNN2C-sep-acc_'+str(index).zfill(1) +'.csv')
    singleModel5644OneTRPWMse = pd.read_csv('transformed_data/model5644multi-6-0-1-TRPWNN2C-sep-mse_'+str(index).zfill(1) +'.csv')
    singleModel5644TRPWAcc = singleModel5644TRPWAcc.append(singleModel5644OneTRPWAcc)
    singleModel5644TRPWMse = singleModel5644TRPWMse.append(singleModel5644OneTRPWMse)

singleModel5644TRPWMse.head()
# Out:
#    Unnamed: 0  epochs  batch  nodos  layer  learning rate       mse      rmse
# 0           0      10     64     16      1          0.002  0.018776  0.063024
# 1           1      10     64     16      2          0.002  0.018234  0.065160
# 2           2      10     64     16      4          0.002  0.019098  0.070034
# 3           3      10     64     16      8          0.002  0.018589  0.071876
# 4           4      10     64     32      1          0.002  0.018591  0.060683

# %%
singleModel5644TRPWAcc
# Out:
#      Unnamed: 0  epochs  batch  nodos  layer  learning rate  keras_loss_model  \
# 0             0      10     64     16      1         0.0020          0.006123
# 1             1      10     64     16      2         0.0020          0.006689
# 2             2      10     64     16      4         0.0020          0.007622
# 3             3      10     64     16      8         0.0020          0.008328
# 4             4      10     64     32      1         0.0020          0.005630
# ..          ...     ...    ...    ...    ...            ...               ...
# 175         175     100    256     32      8         0.0005          0.008993
# 176         176     100    256     64      1         0.0005          0.006254
# 177         177     100    256     64      2         0.0005          0.006709
# 178         178     100    256     64      4         0.0005          0.007827
# 179         179     100    256     64      8         0.0005          0.008594
#
#      keras_model_acc
# 0           0.056058
# 1           0.057830
# 2           0.059681
# 3           0.063231
# 4           0.053542
# ..               ...
# 175         0.070570
# 176         0.057148
# 177         0.061548
# 178         0.067967
# 179         0.070928
#
# [540 rows x 8 columns]

# %%
singleModel5644TRPWMse.columns.values.tolist()
# Out:
# ['Unnamed: 0',
#  'epochs',
#  'batch',
#  'nodos',
#  'layer',
#  'learning rate',
#  'mse',
#  'rmse']

# %%
features_acc = ['epochs', 'batch', 'nodos', 'layer', 'learning rate', 'keras_loss_model', 'keras_model_acc']
singleModel5644TRPWAcc[features_acc]
# Out:
#      epochs  batch  nodos  layer  learning rate  keras_loss_model  \
# 0        10     64     16      1         0.0020          0.006123
# 1        10     64     16      2         0.0020          0.006689
# 2        10     64     16      4         0.0020          0.007622
# 3        10     64     16      8         0.0020          0.008328
# 4        10     64     32      1         0.0020          0.005630
# ..      ...    ...    ...    ...            ...               ...
# 175     100    256     32      8         0.0005          0.008993
# 176     100    256     64      1         0.0005          0.006254
# 177     100    256     64      2         0.0005          0.006709
# 178     100    256     64      4         0.0005          0.007827
# 179     100    256     64      8         0.0005          0.008594
#
#      keras_model_acc
# 0           0.056058
# 1           0.057830
# 2           0.059681
# 3           0.063231
# 4           0.053542
# ..               ...
# 175         0.070570
# 176         0.057148
# 177         0.061548
# 178         0.067967
# 179         0.070928
#
# [540 rows x 7 columns]

# %%
features_mse = ['epochs', 'batch', 'nodos', 'layer', 'learning rate', 'mse', 'rmse']
singleModel5644TRPWMse[features_mse]
# Out:
#      epochs  batch  nodos  layer  learning rate       mse      rmse
# 0        10     64     16      1         0.0020  0.018776  0.063024
# 1        10     64     16      2         0.0020  0.018234  0.065160
# 2        10     64     16      4         0.0020  0.019098  0.070034
# 3        10     64     16      8         0.0020  0.018589  0.071876
# 4        10     64     32      1         0.0020  0.018591  0.060683
# ..      ...    ...    ...    ...            ...       ...       ...
# 175     100    256     32      8         0.0005  0.018179  0.075392
# 176     100    256     64      1         0.0005  0.019096  0.064031
# 177     100    256     64      2         0.0005  0.019212  0.067700
# 178     100    256     64      4         0.0005  0.018889  0.073849
# 179     100    256     64      8         0.0005  0.018676  0.077091
#
# [540 rows x 7 columns]

# %%
singleModel5644TRPWMse.to_csv('transformed_data/memory_data/model5644multi-6-0-1-TRPWNN2C-sep-mse_LSTM.csv', encoding='utf-8')

# %%
idxMse = pd.MultiIndex.from_frame (singleModel5644TRPWMse)
idxAcc = pd.MultiIndex.from_frame (singleModel5644TRPWAcc)

# %%
idxMse
# Out:
# MultiIndex([(  0,  10,  64, 16, 1,  0.002, 0.0187756232917308, ...),
#             (  1,  10,  64, 16, 2,  0.002, 0.0182340573519468, ...),
#             (  2,  10,  64, 16, 4,  0.002, 0.0190976820886135, ...),
#             (  3,  10,  64, 16, 8,  0.002, 0.0185889657586812, ...),
#             (  4,  10,  64, 32, 1,  0.002, 0.0185910165309906, ...),
#             (  5,  10,  64, 32, 2,  0.002, 0.0187742542475461, ...),
#             (  6,  10,  64, 32, 4,  0.002, 0.0194572638720273, ...),
#             (  7,  10,  64, 32, 8,  0.002, 0.0189623925834894, ...),
#             (  8,  10,  64, 64, 1,  0.002, 0.0195372067391872, ...),
#             (  9,  10,  64, 64, 2,  0.002, 0.0198068786412477, ...),
#             ...
#             (170, 100, 256, 16, 4, 0.0005, 0.0177840646356344, ...),
#             (171, 100, 256, 16, 8, 0.0005, 0.0174118038266897, ...),
#             (172, 100, 256, 32, 1, 0.0005, 0.0188446473330259, ...),
#             (173, 100, 256, 32, 2, 0.0005, 0.0186007414013147, ...),
#             (174, 100, 256, 32, 4, 0.0005, 0.0180510394275188, ...),
#             (175, 100, 256, 32, 8, 0.0005, 0.0181787814944982, ...),
#             (176, 100, 256, 64, 1, 0.0005, 0.0190963298082351, ...),
#             (177, 100, 256, 64, 2, 0.0005,  0.019211545586586, ...),
#             (178, 100, 256, 64, 4, 0.0005, 0.0188893005251884, ...),
#             (179, 100, 256, 64, 8, 0.0005, 0.0186762548983097, ...)],
#            names=['Unnamed: 0', 'epochs', 'batch', 'nodos', 'layer', 'learning rate', 'mse', 'rmse'], length=540)

# %%
idxMse.min()
# Out:
# (0, 10, 64, 16, 1, 0.0005, 0.0182512160390615, 0.0699918866157531)

# %%
singleModel5644TRPWMse[singleModel5644TRPWMse['rmse'] < 0.05365]
# Out:
#      Unnamed: 0  epochs  batch  nodos  layer  learning rate       mse  \
# 147         147     100     64     16      8          0.002  0.021192
# 149         149     100     64     32      2          0.002  0.022154
# 163         163     100    128     32      8          0.002  0.021312
# 166         166     100    128     64      4          0.002  0.021409
# 131         131      75    128     64      8          0.001  0.020886
# 147         147     100     64     16      8          0.001  0.021483
# 151         151     100     64     32      8          0.001  0.021357
# 155         155     100     64     64      8          0.001  0.021050
#
#          rmse
# 147  0.053382
# 149  0.053629
# 163  0.053472
# 166  0.053579
# 131  0.053439
# 147  0.053329
# 151  0.053230
# 155  0.053610

# %%
tabla1 = singleModel5644TRPWMse[singleModel5644TRPWMse['rmse'] <0.05365]

# %%
tabla1.to_excel("transformed_data/tablas/model5644multi-6-0-1-TRPWNN2C-sep-rmse_LSTM_min.xlsx")

# %%
idxMse.max()
# Out:
# (179, 100, 256, 64, 8, 0.002, 0.0212625991553068, 0.0546788647770881)

# %%
singleModel5644TRPWMse[singleModel5644TRPWMse['rmse'] > 0.132]
# Out:
#     Unnamed: 0  epochs  batch  nodos  layer  learning rate       mse      rmse
# 27          27      10    256     16      8         0.0010  0.018529  0.135074
# 24          24      10    256     16      1         0.0005  0.048610  0.226106
# 25          25      10    256     16      2         0.0005  0.020679  0.144038
# 26          26      10    256     16      4         0.0005  0.019117  0.135382
# 27          27      10    256     16      8         0.0005  0.019492  0.139527
# 28          28      10    256     32      1         0.0005  0.021263  0.144983
# 31          31      10    256     32      8         0.0005  0.019139  0.137653

# %%
tabla2 = singleModel5644TRPWMse[singleModel5644TRPWMse['rmse'] > 0.132]

# %%
tabla2.to_excel("transformed_data/tablas/model5644multi-6-0-1-TRPWNN2C-sep-rmse_LSTM_max.xlsx")

# %%
singleModel5644TRPWMse['rmse'].mean()
# Out:
# 0.0655854154447162

# %% [markdown]
# ## Datos GRU TRPW Model 5644 (no separarados) 6-0-1

# %%
#OK
singleModel5644TRPWAcc = pd.DataFrame({})
singleModel5644TRPWMse = pd.DataFrame({})
for index in range(0,3):
    singleModel5644OneTRPWAcc = pd.read_csv('transformed_data/model5644multi-6-0-1-TRPWNN2C-acc_GRU_'+str(index).zfill(1) +'.csv')
    singleModel5644OneTRPWMse = pd.read_csv('transformed_data/model5644multi-6-0-1-TRPWNN2C-mse_GRU_'+str(index).zfill(1) +'.csv')
    singleModel5644TRPWAcc = singleModel5644TRPWAcc.append(singleModel5644OneTRPWAcc)
    singleModel5644TRPWMse = singleModel5644TRPWMse.append(singleModel5644OneTRPWMse)

singleModel5644TRPWMse.head()
# Out:
#    Unnamed: 0  epochs  batch  nodos  layer  learning rate       mse      rmse
# 0           0      10     64     16      1          0.002  0.018882  0.058689
# 1           1      10     64     16      2          0.002  0.020016  0.055978
# 2           2      10     64     16      4          0.002  0.020874  0.056448
# 3           3      10     64     16      8          0.002  0.020778  0.057192
# 4           4      10     64     32      1          0.002  0.018947  0.058409

# %%
singleModel5644TRPWMse
# Out:
#      Unnamed: 0  epochs  batch  nodos  layer  learning rate       mse  \
# 0             0      10     64     16      1         0.0020  0.018882
# 1             1      10     64     16      2         0.0020  0.020016
# 2             2      10     64     16      4         0.0020  0.020874
# 3             3      10     64     16      8         0.0020  0.020778
# 4             4      10     64     32      1         0.0020  0.018947
# ..          ...     ...    ...    ...    ...            ...       ...
# 175         175     100    256     32      8         0.0005  0.021506
# 176         176     100    256     64      1         0.0005  0.019111
# 177         177     100    256     64      2         0.0005  0.020805
# 178         178     100    256     64      4         0.0005  0.021586
# 179         179     100    256     64      8         0.0005  0.021928
#
#          rmse
# 0    0.058689
# 1    0.055978
# 2    0.056448
# 3    0.057192
# 4    0.058409
# ..        ...
# 175  0.060333
# 176  0.060658
# 177  0.056775
# 178  0.056525
# 179  0.057639
#
# [540 rows x 8 columns]

# %%
singleModel5644TRPWAcc
# Out:
#      Unnamed: 0  epochs  batch  nodos  layer  learning rate  keras_loss_model  \
# 0             0      10     64     16      1         0.0020          0.005074
# 1             1      10     64     16      2         0.0020          0.004435
# 2             2      10     64     16      4         0.0020          0.004318
# 3             3      10     64     16      8         0.0020          0.004542
# 4             4      10     64     32      1         0.0020          0.004798
# ..          ...     ...    ...    ...    ...            ...               ...
# 175         175     100    256     32      8         0.0005          0.004611
# 176         176     100    256     64      1         0.0005          0.005287
# 177         177     100    256     64      2         0.0005          0.004401
# 178         178     100    256     64      4         0.0005          0.004192
# 179         179     100    256     64      8         0.0005          0.004172
#
#      keras_model_acc
# 0           0.051074
# 1           0.046718
# 2           0.044702
# 3           0.046080
# 4           0.049766
# ..               ...
# 175         0.047065
# 176         0.053031
# 177         0.048878
# 178         0.046428
# 179         0.045530
#
# [540 rows x 8 columns]

# %%
singleModel5644TRPWMse.columns.values.tolist()
# Out:
# ['Unnamed: 0',
#  'epochs',
#  'batch',
#  'nodos',
#  'layer',
#  'learning rate',
#  'mse',
#  'rmse']

# %%
features_acc = ['epochs', 'batch', 'nodos', 'layer', 'learning rate', 'keras_loss_model', 'keras_model_acc']
singleModel5644TRPWAcc = singleModel5644TRPWAcc[features_acc]

# %%
features_mse = ['epochs', 'batch', 'nodos', 'layer', 'learning rate', 'mse', 'rmse']
singleModel5644TRPWMse = singleModel5644TRPWMse[features_mse]

# %%
singleModel5644TRPWMse.to_csv('transformed_data/memory_data/model5644multi-6-0-1-TRPWNN2C-mse_GRU.csv', encoding='utf-8')

# %%
idxMse = pd.MultiIndex.from_frame (singleModel5644TRPWMse)
idxAcc = pd.MultiIndex.from_frame (singleModel5644TRPWAcc)

# %%
idxMse
# Out:
# MultiIndex([( 10,  64, 16, 1,  0.002, 0.0188820790499448, 0.0586885176599025),
#             ( 10,  64, 16, 2,  0.002, 0.0200156401842832, 0.0559783428907394),
#             ( 10,  64, 16, 4,  0.002, 0.0208739601075649, 0.0564483478665351),
#             ( 10,  64, 16, 8,  0.002, 0.0207782983779907, 0.0571924671530723),
#             ( 10,  64, 32, 1,  0.002, 0.0189466886222362, 0.0584093816578388),
#             ( 10,  64, 32, 2,  0.002, 0.0205863062292337, 0.0562663152813911),
#             ( 10,  64, 32, 4,  0.002, 0.0212275739759206, 0.0560326986014843),
#             ( 10,  64, 32, 8,  0.002, 0.0197794083505868, 0.0550544373691082),
#             ( 10,  64, 64, 1,  0.002, 0.0204650145024061, 0.0590194091200828),
#             ( 10,  64, 64, 2,  0.002, 0.0218835212290287, 0.0554959438741207),
#             ...
#             (100, 256, 16, 4, 0.0005,  0.018667509779334, 0.0641925111413002),
#             (100, 256, 16, 8, 0.0005, 0.0181670896708965, 0.0702451542019844),
#             (100, 256, 32, 1, 0.0005, 0.0190977659076452, 0.0623415000736713),
#             (100, 256, 32, 2, 0.0005, 0.0192178543657064, 0.0597738288342952),
#             (100, 256, 32, 4, 0.0005, 0.0214535370469093, 0.0572564378380775),
#             (100, 256, 32, 8, 0.0005, 0.0215055234730243,  0.060333102941513),
#             (100, 256, 64, 1, 0.0005, 0.0191106796264648, 0.0606583580374717),
#             (100, 256, 64, 2, 0.0005, 0.0208046920597553,  0.056775014847517),
#             (100, 256, 64, 4, 0.0005, 0.0215855874121189,  0.056524634361267),
#             (100, 256, 64, 8, 0.0005, 0.0219280514866113, 0.0576385483145713)],
#            names=['epochs', 'batch', 'nodos', 'layer', 'learning rate', 'mse', 'rmse'], length=540)

# %%
idxMse.min()
# Out:
# (10, 64, 16, 1, 0.0005, 0.0192170161753892, 0.0638557150959968)

# %%
singleModel5644TRPWMse[singleModel5644TRPWMse['rmse'] < 0.0543678]
# Out:
#      epochs  batch  nodos  layer  learning rate       mse      rmse
# 152     100     64     64      1         0.0020  0.021447  0.053698
# 159     100    128     16      8         0.0020  0.020867  0.054078
# 167     100    128     64      8         0.0020  0.021108  0.053877
# 111      75     64     16      8         0.0010  0.022060  0.054032
# 147     100     64     16      8         0.0010  0.021437  0.053623
# 151     100     64     32      8         0.0010  0.021025  0.054325
# 157     100    128     16      2         0.0010  0.021273  0.054367
# 161     100    128     32      2         0.0005  0.021209  0.054185

# %%
tabla1 = singleModel5644TRPWMse[singleModel5644TRPWMse['rmse'] < 0.0543678]

# %%
tabla1.to_excel("transformed_data/tablas/model5644multi-6-0-1-TRPWNN2C-rmse_GRU_min.xlsx")

# %%
idxMse.max()
# Out:
# (100, 256, 64, 8, 0.002, 0.0209328960627317, 0.0555675439536571)

# %%
singleModel5644TRPWMse[singleModel5644TRPWMse['rmse'] > 0.087]
# Out:
#     epochs  batch  nodos  layer  learning rate       mse      rmse
# 27      10    256     16      8         0.0020  0.017060  0.087045
# 24      10    256     16      1         0.0010  0.016967  0.114255
# 12      10    128     16      1         0.0005  0.016558  0.102366
# 24      10    256     16      1         0.0005  0.026073  0.164483
# 25      10    256     16      2         0.0005  0.020376  0.140589
# 28      10    256     32      1         0.0005  0.018718  0.128481
# 32      10    256     64      1         0.0005  0.016197  0.087646

# %%
tabla2 = singleModel5644TRPWMse[singleModel5644TRPWMse['rmse'] > 0.087]

# %%
tabla2.to_excel("transformed_data/tablas/model5644multi-6-0-1-TRPWNN2C-rmse_GRU_max.xlsx")

# %%
singleModel5644TRPWMse['rmse'].mean()
# Out:
# 0.06044196231911574

# %% [markdown]
# ## Datos GRU TRPW Model 5644 (separarados) 6-0-1

# %%
#OK
singleModel5644TRPWAcc = pd.DataFrame({})
singleModel5644TRPWMse = pd.DataFrame({})
for index in range(0,3):
    singleModel5644OneTRPWAcc = pd.read_csv('transformed_data/model5644multi-6-0-1-TRPWNN2C-sep-acc_GRU_'+str(index).zfill(1) +'.csv')
    singleModel5644OneTRPWMse = pd.read_csv('transformed_data/model5644multi-6-0-1-TRPWNN2C-sep-mse_GRU_'+str(index).zfill(1) +'.csv')
    singleModel5644TRPWAcc = singleModel5644TRPWAcc.append(singleModel5644OneTRPWAcc)
    singleModel5644TRPWMse = singleModel5644TRPWMse.append(singleModel5644OneTRPWMse)

singleModel5644TRPWMse.head()
# Out:
#    Unnamed: 0  epochs  batch  nodos  layer  learning rate       mse      rmse
# 0           0      10     64     16      1          0.002  0.018941  0.060746
# 1           1      10     64     16      2          0.002  0.018528  0.059288
# 2           2      10     64     16      4          0.002  0.020809  0.055657
# 3           3      10     64     16      8          0.002  0.020911  0.057614
# 4           4      10     64     32      1          0.002  0.019046  0.058001

# %%
singleModel5644TRPWAcc
# Out:
#      Unnamed: 0  epochs  batch  nodos  layer  learning rate  keras_loss_model  \
# 0             0      10     64     16      1         0.0020          0.005435
# 1             1      10     64     16      2         0.0020          0.004977
# 2             2      10     64     16      4         0.0020          0.004297
# 3             3      10     64     16      8         0.0020          0.004593
# 4             4      10     64     32      1         0.0020          0.004741
# ..          ...     ...    ...    ...    ...            ...               ...
# 175         175     100    256     32      8         0.0005          0.004514
# 176         176     100    256     64      1         0.0005          0.005483
# 177         177     100    256     64      2         0.0005          0.004281
# 178         178     100    256     64      4         0.0005          0.004180
# 179         179     100    256     64      8         0.0005          0.004184
#
#      keras_model_acc
# 0           0.053167
# 1           0.050375
# 2           0.044721
# 3           0.046752
# 4           0.049131
# ..               ...
# 175         0.046308
# 176         0.053473
# 177         0.047577
# 178         0.046315
# 179         0.045505
#
# [540 rows x 8 columns]

# %%
singleModel5644TRPWMse.columns.values.tolist()
# Out:
# ['Unnamed: 0',
#  'epochs',
#  'batch',
#  'nodos',
#  'layer',
#  'learning rate',
#  'mse',
#  'rmse']

# %%
features_acc = ['epochs', 'batch', 'nodos', 'layer', 'learning rate', 'keras_loss_model', 'keras_model_acc']
singleModel5644TRPWAcc = singleModel5644TRPWAcc[features_acc]

# %%
features_mse = ['epochs', 'batch', 'nodos', 'layer', 'learning rate', 'mse', 'rmse']
singleModel5644TRPWMse = singleModel5644TRPWMse[features_mse]

# %%
singleModel5644TRPWMse.to_csv('transformed_data/memory_data/model5644multi-6-0-1-TRPWNN2C-sep-mse_GRU.csv', encoding='utf-8')

# %%
idxMse = pd.MultiIndex.from_frame (singleModel5644TRPWMse)
idxAcc = pd.MultiIndex.from_frame (singleModel5644TRPWAcc)

# %%
idxMse
# Out:
# MultiIndex([( 10,  64, 16, 1,  0.002, 0.0189410280436277, 0.0607464239001274),
#             ( 10,  64, 16, 2,  0.002, 0.0185280479490757, 0.0592884048819541),
#             ( 10,  64, 16, 4,  0.002, 0.0208087470382452, 0.0556568764150142),
#             ( 10,  64, 16, 8,  0.002, 0.0209109429270029, 0.0576137937605381),
#             ( 10,  64, 32, 1,  0.002, 0.0190463196486234, 0.0580011345446109),
#             ( 10,  64, 32, 2,  0.002, 0.0211880970746278, 0.0553450770676136),
#             ( 10,  64, 32, 4,  0.002, 0.0213656555861234, 0.0561385005712509),
#             ( 10,  64, 32, 8,  0.002, 0.0199935175478458, 0.0550289191305637),
#             ( 10,  64, 64, 1,  0.002, 0.0207782667130231, 0.0584598034620285),
#             ( 10,  64, 64, 2,  0.002, 0.0217097103595733, 0.0558441989123821),
#             ...
#             (100, 256, 16, 4, 0.0005, 0.0188333317637443,  0.062586210668087),
#             (100, 256, 16, 8, 0.0005, 0.0202980618923902, 0.0720831602811813),
#             (100, 256, 32, 1, 0.0005, 0.0190542042255401, 0.0617030970752239),
#             (100, 256, 32, 2, 0.0005,  0.019432783126831, 0.0583850592374801),
#             (100, 256, 32, 4, 0.0005, 0.0210020542144775, 0.0579751804471015),
#             (100, 256, 32, 8, 0.0005, 0.0217032488435506, 0.0597753226757049),
#             (100, 256, 64, 1, 0.0005, 0.0190540552139282, 0.0611085146665573),
#             (100, 256, 64, 2, 0.0005, 0.0212293118238449,  0.056451465934515),
#             (100, 256, 64, 4, 0.0005, 0.0218039695173501, 0.0569511540234088),
#             (100, 256, 64, 8, 0.0005, 0.0219387002289295,  0.057686548680067)],
#            names=['epochs', 'batch', 'nodos', 'layer', 'learning rate', 'mse', 'rmse'], length=540)

# %%
idxMse.min()
# Out:
# (10, 64, 16, 1, 0.0005, 0.019272893667221, 0.0638770535588264)

# %%
singleModel5644TRPWMse[singleModel5644TRPWMse['rmse'] < 0.05415]
# Out:
#      epochs  batch  nodos  layer  learning rate       mse      rmse
# 123      75    128     16      8          0.002  0.022387  0.054017
# 152     100     64     64      1          0.002  0.021895  0.053812
# 158     100    128     16      4          0.002  0.021105  0.053814
# 165     100    128     64      2          0.002  0.021310  0.053924
# 146     100     64     16      4          0.001  0.021812  0.053802
# 147     100     64     16      8          0.001  0.021332  0.054108
# 149     100     64     32      2          0.001  0.021809  0.053979
# 153     100     64     64      2          0.001  0.021617  0.053954

# %%
tabla1 = singleModel5644TRPWMse[singleModel5644TRPWMse['rmse'] < 0.05415]

# %%
tabla1.to_excel("transformed_data/tablas/model5644multi-6-0-1-TRPWNN2C-sep-rmse_GRU_min.xlsx")

# %%
idxMse.max()
# Out:
# (100, 256, 64, 8, 0.002, 0.020895566791296, 0.0561787709593772)

# %%
singleModel5644TRPWMse[singleModel5644TRPWMse['rmse'] > 0.082]
# Out:
#     epochs  batch  nodos  layer  learning rate       mse      rmse
# 27      10    256     16      8         0.0020  0.017654  0.084716
# 24      10    256     16      1         0.0010  0.017144  0.114069
# 12      10    128     16      1         0.0005  0.016591  0.096385
# 24      10    256     16      1         0.0005  0.028318  0.175373
# 25      10    256     16      2         0.0005  0.019155  0.127630
# 26      10    256     16      4         0.0005  0.017072  0.093648
# 28      10    256     32      1         0.0005  0.019463  0.130507

# %%
tabla2 = singleModel5644TRPWMse[singleModel5644TRPWMse['rmse'] > 0.082]

# %%
tabla2.to_excel("transformed_data/tablas/model5644multi-6-0-1-TRPWNN2C-sep-rmse_GRU_max.xlsx")

# %%
singleModel5644TRPWMse['rmse'].mean()
# Out:
# 0.060526828012532605
